# %% [markdown]
# # Backpropagation
#
# #### Synopsis
# This is a small script I wrote which stimulates a small neural network ( two input nodes, three hidden layers of one node each, and one output node). This script first creates the structure and assignes random weights and biases, which are later fine tuned through backpropogation. The data fed to the model is a diabetes dataset, where the model tries to predict if a patient has diabetes (0 or 1), given their BMI and Glucose level.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import random as rnd
import math

print("setup complete")
# Out:
# setup complete

# %%
df = pd.read_csv('diabetes.csv')
x_train, x_test, x2_train, x2_test, y_train, y_test = \
train_test_split(df['Glucose'],df['BMI'], df['Outcome'], test_size=0.2, random_state = 82)



x_train,x_test, x2_train, x2_test, y_train, y_test =\
x_train.values.tolist(), x_test.values.tolist(),x2_train.values.tolist(), x2_test.values.tolist(),\
y_train.values.tolist(), y_test.values.tolist()

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
#Start with random weights and biases

layers = 4 
np.random.RandomState(seed =4)
w = [np.random.rand() for i in range(layers)]
b = [np.random.rand() for i in range(layers)]
w2 = [np.random.rand() for i in range(layers)]
b2 = [np.random.rand() for i in range(layers)]

# %%
#define the sigmoid squish function
def sig(x):
    return 1/(1+(math.e**-x))

#create a function to compute Average Squared Sum Errors 
def ASSE(w,b,data,ans):
    SSE = 0
    for i in range(len(data)):
        SSE += (output(data[i])-ans[i])**2 
    return SSE/len(data)

#create a function to see the output of a single entry
def output (value):
    result = value
    for item in range(len(w)):
        result = sig(result*w[item]+b[item])
    return result

#create a function to see which direction and how much model should move
def des_change(output,desired_output):
    return desired_output-output

#create a function to see the cost of a single entry
def cost(output,desired_output):
    return (output-desired_output)**2

# %%
#check how accurate random biases and weights are, the value is the average of how off you would be for every guess
#using the current model, i.e. 0.3 means that for every guess you could expect to be 30% above or below

print(ASSE(w,b,x_test,y_test))
# Out:
# 0.4461973072992946

# %%
#Define the derivatives relative to the cost function

####
#relevent derivatives:
#
#C/a = 2*(a - y)           #alpha of the output layer
#
#a/z = sig(z)*(1-sig(z))   #zeta of whichever layer you are on i.e. for hidden layer 1 it is z1
#
#z/w = a                   #alpha of the node the weight is attached to
#
#z/b = 1                   #since we are using chain rule, this has no effect on outcomes as 1*x is x
#
#z/a = w                   #weight of alpha node connected to i.e. z2/a2 = w2
####
#derivative of weight
def cd(a,y):
    Cderivative = 2*(a-y)
    return Cderivative
    
    
#derivative of bias
def ad(z):
    Bderivative =sig(z)*(1-sig(z))
    return Bderivative

# %%
#to calculate the derivative of any given node in the hidden layer use the derivative of bias function
#which derives the node to its zeta, the zeta to its alpha, and the final alpha to the cost function.
#all that remains is to multiply it by the remaining zeta and alpha derivatives that are inbetween

#formula for remaining derivatives is Wx*(sig(Zx)*(1-sig(Zx))) for every layer between


def forwardProp(x,x2):
    a = [x]
    a2 = [x2]
    z = []
    for i in range(len(w)):
        if i == 0:
            z.append(a[i]*w[i] +b[i] + (a2[i]*w2[i]+b2[i]))
        elif i != 0:
            z.append(a[i]*w[i] +b[i])
        a.append(sig(z[i]))
    return a,a2,z


def backProp(a,a2,z,y):
    wd= []
    bd= []
    w2d= []
    b2d= []
    for i in range(len(w)):
        tempw = ad(z[-1])*cd(a[-1],y)
        tempb = ad(z[-1])*cd(a[-1],y)
        x = i # x = 0
        while x <(len(w)-1): 
            tempw = tempw*a[x]*ad(z[x])*w[x+1]
            tempb = tempb*ad(z[x])*w[x+1]
            if x < 1:
                tempw2 = tempw*a2[x]*ad(z[x])*w2[x+1]
                tempb2 = tempb*ad(z[x])*w2[x+1]
            x += 1
        wd.append(tempw)
        bd.append(tempb)
        w2d.append(tempw2)
        b2d.append(tempb2)
    return wd, bd, w2d, b2d

# %%
a,a2,z = forwardProp(x_train[0],x2_train[0])

a
#wd, bd, w2d, b2d =backProp(a,z,y_train[0])
# Out:
# [88, 1.0, 0.6808626621720735, 0.7011918613056777, 0.7890851138393173]

# %%
totalWD = [0 for i in range(len(w))]
totalBD = [0 for i in range(len(b))]

for i in x_train:
    a,a2,z = forwardProp(x_train[i],x2_train[i])
    wd,bd,w2d,b2d = backProp(a,a2,z,y_train[x_train.index(i)])
    for e in range(len(w)):
        totalWD[e] += wd[e]
        totalBD[e] += bd[e]
print('total weight1 derivative: ',totalWD[0])
print('total weight2 derivative: ',totalWD[1])
print('total Bias1 derivative:   ',totalBD[0])
print('total Bias2 derivative:   ',totalBD[1])
print()
print('total average cost:     ', ASSE(w,b,x_train,y_train))

change = sum(des_change(output(x_train[i]),y_train[i]) for i in range(len(x_train)))/len(x_train)
print('desired average change: ',change)
# Out:
# total weight1 derivative:  0.0
# total weight2 derivative:  0.556589269849143
# total Bias1 derivative:    0.0
# total Bias2 derivative:    0.8174765643243367
#
# total average cost:      0.41455042964071603
# desired average change:  -0.4291480606631066

# %%
def train (totalWD,totalBD,learning_rate,change):
    
    if abs(max(totalWD) > abs(min(totalWD))):
        change_weight_index = totalWD.index(max(totalWD)) 
    else:
        change_weight_index = totalWD.index(min(totalWD))
    if abs(max(totalBD)) > abs(min(totalBD)):
        change_bias_index = totalBD.index(max(totalBD))
    else:
         change_bias_index = totalBD.index(min(totalBD))
    
    
    print('weight change: ',change*learning_rate*(abs(totalWD[change_weight_index])**0.5))
    print('bias change: ', change*learning_rate*(abs(totalBD[change_bias_index])**0.5))
    w[change_weight_index] += change*learning_rate*(abs(totalWD[change_weight_index])**0.5)
    b[change_bias_index] += change*learning_rate*(abs(totalBD[change_bias_index])**0.5)

# %%
def epochs(learning_rate,iterations):
    x=0
    while x <iterations: 
        totalWD = [0 for i in range(len(w))]
        totalBD = [0 for i in range(len(b))]
        
        for i in x_train:
            a,a2,z = forwardProp(x_train[i],x2_train[i])
            wd,bd,w2d,b2d = backProp(a,a2,z,y_train[x_train.index(i)])
            for e in range(len(w)):
                totalWD[e] += wd[e]
                totalBD[e] += bd[e]
        for item in range(len(w)):
            print('w',item,': ',w[item])
            print('b',item,': ',b[item])
            if item == 0 :
                print('w2 0: ',w2[0])
                print('b2 0: ',b2[0])
            print('total weight',item,'derivative:  ',totalWD[item])
            print('total Bias',item,'derivative:    ',totalBD[item])
            print()
        print()
        print('total average cost:     ', ASSE(w,b,x_train,y_train))
        
        change = sum(des_change(output(x_train[i]),y_train[i]) for i in range(len(x_train)))/len(x_train)
        print('desired average change: ',change)
        print('iteration:',x)
        train(totalWD,totalBD,learning_rate,change)
        x +=1
        print('\n'*3)
        print('--------------------------------------')

# %%
epochs(1,100)
# Out:
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.556589269849143
# total Bias 1 derivative:     0.8174765643243367
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   9.983491796834716
# total Bias 2 derivative:     14.663003791374948
#
# w 3 :  0.8778700177184595
# b 3 :  0.7038642099372739
# total weight 3 derivative:   79.71929353230342
# total Bias 3 derivative:     79.71929353230342
#
#
# total average cost:      0.41455042964071603
# desired average change:  -0.4291480606631066
# iteration: 0
# weight change:  -3.8316768486730304
# bias change:  -3.8316768486730304
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.06200422121283557
# total Bias 1 derivative:     0.09106714857153574
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   1.1121641529583397
# total Bias 2 derivative:     1.6334632735041341
#
# w 3 :  -2.953806830954571
# b 3 :  -3.1278126387357563
# total weight 3 derivative:   -2.6393561368533596
# total Bias 3 derivative:     -2.6393561368533596
#
#
# total average cost:      0.35601141391738855
# desired average change:  0.35444284084557226
# iteration: 1
# weight change:  0.5758312183746396
# bias change:  0.5758312183746396
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.12756519923042034
# total Bias 1 derivative:     0.1873581947106115
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   2.2881255336159834
# total Bias 2 derivative:     3.360627128996051
#
# w 3 :  -2.3779756125799314
# b 3 :  -2.5519814203611166
# total weight 3 derivative:   -6.745026242308677
# total Bias 3 derivative:     -6.745026242308677
#
#
# total average cost:      0.34971042443236877
# desired average change:  0.3454400284295415
# iteration: 2
# weight change:  0.8971488041438893
# bias change:  0.8971488041438893
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.2881526270222386
# total Bias 1 derivative:     0.42321696141037063
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   5.16856781822722
# total Bias 2 derivative:     7.591204666354525
#
# w 3 :  -1.480826808436042
# b 3 :  -1.6548326162172273
# total weight 3 derivative:   -24.466798402112254
# total Bias 3 derivative:     -24.466798402112254
#
#
# total average cost:      0.31832703501111026
# desired average change:  0.2965563203029405
# iteration: 3
# weight change:  1.4668839477240563
# bias change:  1.4668839477240563
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   -0.0017431590847085227
# total Bias 1 derivative:     -0.0025602212921289028
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   -0.03126688810850084
# total Bias 2 derivative:     -0.04592245961726509
#
# w 3 :  -0.013942860711985805
# b 3 :  -0.18794866849317104
# total weight 3 derivative:   15.719689490561162
# total Bias 3 derivative:     15.719689490561162
#
#
# total average cost:      0.23862534389225099
# desired average change:  -0.09079429348045563
# iteration: 4
# weight change:  -0.3599817924521485
# bias change:  -0.3599817924521485
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.07093683028289118
# total Bias 1 derivative:     0.1041866946508572
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   1.272387560426088
# total Bias 2 derivative:     1.8687873944606879
#
# w 3 :  -0.3739246531641343
# b 3 :  -0.5479304609453195
# total weight 3 derivative:   -23.853192202227195
# total Bias 3 derivative:     -23.853192202227195
#
#
# total average cost:      0.23309264669182642
# desired average change:  0.052069450457182684
# iteration: 5
# weight change:  0.254305789824543
# bias change:  0.254305789824543
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   -0.0021726447802027497
# total Bias 1 derivative:     -0.003191017661728809
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   -0.038970534495695076
# total Bias 2 derivative:     -0.05723699750456589
#
# w 3 :  -0.11961886333959132
# b 3 :  -0.2936246711207765
# total weight 3 derivative:   2.283746441388303
# total Bias 3 derivative:     2.283746441388303
#
#
# total average cost:      0.2325714501635849
# desired average change:  -0.046795481539948024
# iteration: 6
# weight change:  -0.07071765686457074
# bias change:  -0.07071765686457074
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.00916404213104598
# total Bias 1 derivative:     0.01345945759723554
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.16437460151889255
# total Bias 2 derivative:     0.24142108335696882
#
# w 3 :  -0.19033652020416206
# b 3 :  -0.36434232798534727
# total weight 3 derivative:   -6.053740219931622
# total Bias 3 derivative:     -6.053740219931622
#
#
# total average cost:      0.23070999185702845
# desired average change:  -0.018122519991756247
# iteration: 7
# weight change:  -0.04458928185244519
# bias change:  -0.04458928185244519
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020430753313993053
# total Bias 1 derivative:     0.03000715775603733
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.36646458917306723
# total Bias 2 derivative:     0.5382356964677383
#
# w 3 :  -0.23492580205660724
# b 3 :  -0.4089316098377925
# total weight 3 derivative:   -10.934841446198593
# total Bias 3 derivative:     -10.934841446198593
#
#
# total average cost:      0.23038173699908163
# desired average change:  -0.0004587660923172073
# iteration: 8
# weight change:  -0.0015170418321650912
# bias change:  -0.0015170418321650912
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02086416107679781
# total Bias 1 derivative:     0.03064371456387039
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3742385853297317
# total Bias 2 derivative:     0.5496535588188122
#
# w 3 :  -0.23644284388877232
# b 3 :  -0.4104486516699576
# total weight 3 derivative:   -11.095160295694342
# total Bias 3 derivative:     -11.095160295694342
#
#
# total average cost:      0.23038154369687153
# desired average change:  0.00013590962749018785
# iteration: 9
# weight change:  0.00045270679443781153
# bias change:  0.00045270679443781153
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02073449823945958
# total Bias 1 derivative:     0.030453275515671528
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3719128346495675
# total Bias 2 derivative:     0.5462376706971942
#
# w 3 :  -0.2359901370943345
# b 3 :  -0.40999594487551977
# total weight 3 derivative:   -11.047359986197252
# total Bias 3 derivative:     -11.047359986197252
#
#
# total average cost:      0.23038152733794914
# desired average change:  -4.150507636106147e-05
# iteration: 10
# weight change:  -0.0001379527842891255
# bias change:  -0.0001379527842891255
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020773980736374043
# total Bias 1 derivative:     0.030511264445169183
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3726210286544018
# total Bias 2 derivative:     0.5472778129229167
#
# w 3 :  -0.23612808987862363
# b 3 :  -0.4101338976598089
# total weight 3 derivative:   -11.061929823634397
# total Bias 3 derivative:     -11.061929823634397
#
#
# total average cost:      0.23038152565427217
# desired average change:  1.2562343730055169e-05
# iteration: 11
# weight change:  4.1781701484810735e-05
# bias change:  4.1781701484810735e-05
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020762019958151124
# total Bias 1 derivative:     0.03049369735141097
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37240648924852426
# total Bias 2 derivative:     0.5469627135382629
#
# w 3 :  -0.23608630817713883
# b 3 :  -0.41009211595832407
# total weight 3 derivative:   -11.057517406167442
# total Bias 3 derivative:     -11.057517406167442
#
#
# total average cost:      0.23038152554698024
# desired average change:  -3.8126577317903834e-06
# iteration: 12
# weight change:  -1.2678171888771137e-05
# bias change:  -1.2678171888771137e-05
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020765649066586237
# total Bias 1 derivative:     0.030499027513625633
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724715842409316
# total Bias 2 derivative:     0.5470583201796949
#
# w 3 :  -0.2360989863490276
# b 3 :  -0.41010479413021284
# total weight 3 derivative:   -11.058856334486624
# total Bias 3 derivative:     -11.058856334486624
#
#
# total average cost:      0.23038152552286123
# desired average change:  1.156180672147695e-06
# iteration: 13
# weight change:  3.844862499331518e-06
# bias change:  3.844862499331518e-06
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764548457154627
# total Bias 1 derivative:     0.0304974110210591
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245184270828974
# total Bias 2 derivative:     0.5470293252975632
#
# w 3 :  -0.23609514148652827
# b 3 :  -0.4101009492677135
# total weight 3 derivative:   -11.058450285525671
# total Bias 3 derivative:     -11.058450285525671
#
#
# total average cost:      0.23038152552496033
# desired average change:  -3.506974805073278e-07
# iteration: 14
# weight change:  -1.166218108735308e-06
# bias change:  -1.166218108735308e-06
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764882290285693
# total Bias 1 derivative:     0.030497901330118787
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245783064322174
# total Bias 2 derivative:     0.547038119927177
#
# w 3 :  -0.236096307704637
# b 3 :  -0.41010211548582226
# total weight 3 derivative:   -11.058573447973545
# total Bias 3 derivative:     -11.058573447973545
#
#
# total average cost:      0.23038152552384294
# desired average change:  1.0636690374054871e-07
# iteration: 15
# weight change:  3.537171122869125e-07
# bias change:  3.537171122869125e-07
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764781037597185
# total Bias 1 derivative:     0.030497752617765904
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245601448282617
# total Bias 2 derivative:     0.547035452487036
#
# w 3 :  -0.2360959539875247
# b 3 :  -0.41010176176871
# total weight 3 derivative:   -11.05853609249396
# total Bias 3 derivative:     -11.05853609249396
#
#
# total average cost:      0.23038152552413632
# desired average change:  -3.2261935489738466e-08
# iteration: 16
# weight change:  -1.0728505750287358e-07
# bias change:  -1.0728505750287358e-07
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764811748280338
# total Bias 1 derivative:     0.030497797723312868
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724565653375958
# total Bias 2 derivative:     0.5470362615411878
#
# w 3 :  -0.2360960612725822
# b 3 :  -0.4101018690537675
# total weight 3 derivative:   -11.058547422693636
# total Bias 3 derivative:     -11.058547422693636
#
#
# total average cost:      0.23038152552404473
# desired average change:  9.78523542469253e-09
# iteration: 17
# weight change:  3.2540207742670364e-08
# bias change:  3.2540207742670364e-08
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764802433542548
# total Bias 1 derivative:     0.030497784042524727
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245639825997545
# total Bias 2 derivative:     0.5470360161501278
#
# w 3 :  -0.23609602873237445
# b 3 :  -0.41010183651355975
# total weight 3 derivative:   -11.05854398617585
# total Bias 3 derivative:     -11.05854398617585
#
#
# total average cost:      0.23038152552407165
# desired average change:  -2.9679260462586146e-09
# iteration: 18
# weight change:  -9.86965677498829e-09
# bias change:  -9.86965677498829e-09
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764805258762484
# total Bias 1 derivative:     0.030497788191996902
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245644893570307
# total Bias 2 derivative:     0.5470360905788246
#
# w 3 :  -0.23609603860203124
# b 3 :  -0.4101018463832165
# total weight 3 derivative:   -11.0585450284941
# total Bias 3 derivative:     -11.0585450284941
#
#
# total average cost:      0.23038152552406263
# desired average change:  9.001907898070669e-10
# iteration: 19
# weight change:  2.993529625614206e-09
# bias change:  2.993529625614206e-09
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804401855724
# total Bias 1 derivative:     0.030497786933435328
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643356543107
# total Bias 2 derivative:     0.5470360680041314
#
# w 3 :  -0.23609603560850162
# b 3 :  -0.41010184338968686
# total weight 3 derivative:   -11.058544712352429
# total Bias 3 derivative:     -11.058544712352429
#
#
# total average cost:      0.2303815255240654
# desired average change:  -2.7303358054366705e-10
# iteration: 20
# weight change:  -9.079565240133052e-10
# bias change:  -9.079565240133052e-10
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480466176078
# total Bias 1 derivative:     0.030497787315165385
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643822733354
# total Bias 2 derivative:     0.5470360748511733
#
# w 3 :  -0.23609603651645814
# b 3 :  -0.4101018442976434
# total weight 3 derivative:   -11.058544808240033
# total Bias 3 derivative:     -11.058544808240033
#
#
# total average cost:      0.23038152552406638
# desired average change:  8.281278666791916e-11
# iteration: 21
# weight change:  2.753888737902639e-10
# bias change:  2.753888737902639e-10
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480458293
# total Bias 1 derivative:     0.030497787199384098
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724564368133509
# total Bias 2 derivative:     0.5470360727744255
#
# w 3 :  -0.23609603624106926
# b 3 :  -0.4101018440222545
# total weight 3 derivative:   -11.058544779156874
# total Bias 3 derivative:     -11.058544779156874
#
#
# total average cost:      0.23038152552406366
# desired average change:  -2.511771283183187e-11
# iteration: 22
# weight change:  -8.35274227346981e-11
# bias change:  -8.35274227346981e-11
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804606840277
# total Bias 1 derivative:     0.030497787234501077
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724564372422252
# total Bias 2 derivative:     0.5470360734043218
#
# w 3 :  -0.2360960363245967
# b 3 :  -0.41010184410578193
# total weight 3 derivative:   -11.058544787977986
# total Bias 3 derivative:     -11.058544787977986
#
#
# total average cost:      0.23038152552406538
# desired average change:  7.618446771015629e-12
# iteration: 23
# weight change:  2.5334680292696378e-11
# bias change:  2.5334680292696378e-11
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480459958762
# total Bias 1 derivative:     0.03049778722384982
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724564371121441
# total Bias 2 derivative:     0.5470360732132649
#
# w 3 :  -0.236096036299262
# b 3 :  -0.41010184408044725
# total weight 3 derivative:   -11.058544785302413
# total Bias 3 derivative:     -11.058544785302413
#
#
# total average cost:      0.23038152552406616
# desired average change:  -2.310733942228502e-12
# iteration: 24
# weight change:  -7.684204854391174e-12
# bias change:  -7.684204854391174e-12
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601787763
# total Bias 1 derivative:     0.030497787227080728
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724564371515957
# total Bias 2 derivative:     0.5470360732712084
#
# w 3 :  -0.23609603630694623
# b 3 :  -0.41010184408813144
# total weight 3 derivative:   -11.058544786113943
# total Bias 3 derivative:     -11.058544786113943
#
#
# total average cost:      0.23038152552406352
# desired average change:  7.00911641430518e-13
# iteration: 25
# weight change:  2.3308389336173503e-12
# bias change:  2.3308389336173503e-12
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460112007
# total Bias 1 derivative:     0.0304977872261002
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643713962306
# total Bias 2 derivative:     0.5470360732536332
#
# w 3 :  -0.2360960363046154
# b 3 :  -0.4101018440858006
# total weight 3 derivative:   -11.058544785867689
# total Bias 3 derivative:     -11.058544785867689
#
#
# total average cost:      0.23038152552406638
# desired average change:  -2.1259902994777252e-13
# iteration: 26
# weight change:  -7.069851133228104e-13
# bias change:  -7.069851133228104e-13
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460132284
# total Bias 1 derivative:     0.03049778722639762
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.372456437143261
# total Bias 2 derivative:     0.5470360732589735
#
# w 3 :  -0.2360960363053224
# b 3 :  -0.41010184408650757
# total weight 3 derivative:   -11.058544785942573
# total Bias 3 derivative:     -11.058544785942573
#
#
# total average cost:      0.23038152552406727
# desired average change:  6.451046718168031e-14
# iteration: 27
# weight change:  2.1452562583331752e-13
# bias change:  2.1452562583331752e-13
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601261167
# total Bias 1 derivative:     0.030497787226307665
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714215576
# total Bias 2 derivative:     0.5470360732573534
#
# w 3 :  -0.23609603630510786
# b 3 :  -0.410101844086293
# total weight 3 derivative:   -11.058544785919691
# total Bias 3 derivative:     -11.058544785919691
#
#
# total average cost:      0.23038152552406538
# desired average change:  -1.9643714812577812e-14
# iteration: 28
# weight change:  -6.532397606092395e-14
# bias change:  -6.532397606092395e-14
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601280162
# total Bias 1 derivative:     0.030497787226335178
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.372456437142496
# total Bias 2 derivative:     0.5470360732578473
#
# w 3 :  -0.2360960363051732
# b 3 :  -0.41010184408635836
# total weight 3 derivative:   -11.05854478592672
# total Bias 3 derivative:     -11.05854478592672
#
#
# total average cost:      0.23038152552406643
# desired average change:  5.938789091333655e-15
# iteration: 29
# weight change:  1.9749081074261932e-14
# bias change:  1.9749081074261932e-14
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601274237
# total Bias 1 derivative:     0.030497787226326914
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714239024
# total Bias 2 derivative:     0.5470360732576992
#
# w 3 :  -0.23609603630515344
# b 3 :  -0.4101018440863386
# total weight 3 derivative:   -11.058544785924665
# total Bias 3 derivative:     -11.058544785924665
#
#
# total average cost:      0.23038152552406657
# desired average change:  -1.7741870224140125e-15
# iteration: 30
# weight change:  -5.899950782506397e-15
# bias change:  -5.899950782506397e-15
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601276072
# total Bias 1 derivative:     0.030497787226329447
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.3724564371424206
# total Bias 2 derivative:     0.5470360732577405
#
# w 3 :  -0.23609603630515935
# b 3 :  -0.4101018440863445
# total weight 3 derivative:   -11.058544785925179
# total Bias 3 derivative:     -11.058544785925179
#
#
# total average cost:      0.230381525524067
# desired average change:  5.164164427246657e-16
# iteration: 31
# weight change:  1.7173113977617877e-15
# bias change:  1.7173113977617877e-15
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.020764804601275496
# total Bias 1 derivative:     0.03049778722632828
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241844
# total Bias 2 derivative:     0.5470360732577259
#
# w 3 :  -0.23609603630515763
# b 3 :  -0.41010184408634276
# total weight 3 derivative:   -11.058544785924877
# total Bias 3 derivative:     -11.058544785924877
#
#
# total average cost:      0.23038152552406693
# desired average change:  -1.0378957917505535e-16
# iteration: 32
# weight change:  -3.4514591817760947e-16
# bias change:  -3.4514591817760947e-16
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 33
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 34
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 35
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 36
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 37
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 38
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 39
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 40
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 41
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 42
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 43
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 44
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 45
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 46
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 47
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 48
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 49
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 50
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 51
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 52
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 53
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 54
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 55
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# ...
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 81
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 82
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 83
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 84
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 85
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 86
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 87
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 88
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 89
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 90
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 91
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 92
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 93
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 94
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 95
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 96
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 97
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 98
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
# w 0 :  0.7109659358673398
# b 0 :  0.6248865003504928
# w2 0:  0.9268613402114424
# b2 0:  0.40293420081441755
# total weight 0 derivative:   0.0
# total Bias 0 derivative:     0.0
#
# w 1 :  0.5480285449209549
# b 1 :  0.2097105338295635
# total weight 1 derivative:   0.02076480460127553
# total Bias 1 derivative:     0.030497787226328316
#
# w 2 :  0.2565755258520438
# b 2 :  0.6782871597705876
# total weight 2 derivative:   0.37245643714241583
# total Bias 2 derivative:     0.5470360732577262
#
# w 3 :  -0.23609603630515796
# b 3 :  -0.4101018440863431
# total weight 3 derivative:   -11.058544785925129
# total Bias 3 derivative:     -11.058544785925129
#
#
# total average cost:      0.23038152552406693
# desired average change:  3.6163616437301518e-19
# iteration: 99
# weight change:  1.202599018040465e-18
# bias change:  1.202599018040465e-18
#
#
#
#
# --------------------------------------
